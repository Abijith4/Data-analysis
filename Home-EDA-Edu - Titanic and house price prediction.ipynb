# %%
#objective of the eda 
#1. is to clean and filter the data from redundancies 

#i.Help us to find out the faulty points in data if we find the faulty points we 
#  can easily remove them and clean the data 

#ii.EDA help us to understand the relationship between the variables which gives us 
#  a wider perspective on the data and it actually helps us build on it by utilizing 
#  them relationship between them variables so these are the main objectives of performing EDA 
#  on any data

# %%
# steps involved in exploratory data analysis 
#      i.Understand the variables line (num of colms & Rows) in the dataset 
#      ii.clean the data from the redundancies (redundancies can be irregularity in the data
#         it can be some variables or some columns that are not necessary for making our 
#         conclusions or interpretations so we can just remove them or they are outliers which can cause noise 
#         in the data or we know it may over fit or under fit the model when we are working on it for modell building 
#      iii.Analysis of relationship between variables.

# %%
import pandas as pd
import numpy as np
import seaborn as sns # visualization relation between the variables we are using it

# %%
data=pd.read_csv("C:/Users/91944/Downloads/houseprices.csv")

# %%
data
# Out:
#        Price  Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace
# 0     142212         1982        1.0         3      2.00  133          0
# 1     134865         1676        1.5         3      0.38   14          1
# 2     118007         1694        2.0         3      0.96   15          1
# 3     138297         1800        1.0         2      0.48   49          1
# 4     129470         2088        1.0         3      1.84   29          1
# ...      ...          ...        ...       ...       ...  ...        ...
# 1042  107695         1802        2.0         4      0.97   56          1
# 1043  236737         3239        3.5         4      2.50    1          1
# 1044  154829         1440        2.0         2      0.61   66          1
# 1045  179492         2030        2.5         3      1.00    3          1
# 1046  189108         2097        2.5         3      1.93   10          1
#
# [1047 rows x 7 columns]

# %%
#1 Understanding the data

# %%
data.head(5)
# Out:
#     Price  Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace
# 0  142212         1982        1.0         3      2.00  133          0
# 1  134865         1676        1.5         3      0.38   14          1
# 2  118007         1694        2.0         3      0.96   15          1
# 3  138297         1800        1.0         2      0.48   49          1
# 4  129470         2088        1.0         3      1.84   29          1

# %%
data.tail(5)
# Out:
#        Price  Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace
# 1042  107695         1802        2.0         4      0.97   56          1
# 1043  236737         3239        3.5         4      2.50    1          1
# 1044  154829         1440        2.0         2      0.61   66          1
# 1045  179492         2030        2.5         3      1.00    3          1
# 1046  189108         2097        2.5         3      1.93   10          1

# %%
data.shape
# Out:
# (1047, 7)

# %%
data.describe()
# Out:
#                Price  Living Area    Bathrooms     Bedrooms     Lot Size  \
# count    1047.000000  1047.000000  1047.000000  1047.000000  1047.000000
# mean   163862.125119  1807.302770     1.918338     3.183381     0.569580
# std     67651.558917   641.460916     0.641735     0.750265     0.777879
# min     16858.000000   672.000000     1.000000     1.000000     0.000000
# 25%    112014.000000  1336.000000     1.500000     3.000000     0.210000
# 50%    151917.000000  1672.000000     2.000000     3.000000     0.390000
# 75%    205235.000000  2206.000000     2.500000     4.000000     0.600000
# max    446436.000000  4534.000000     4.500000     6.000000     9.000000
#
#                Age    Fireplace
# count  1047.000000  1047.000000
# mean     28.061127     0.593123
# std      34.900899     0.491486
# min       0.000000     0.000000
# 25%       6.000000     0.000000
# 50%      18.000000     1.000000
# 75%      34.000000     1.000000
# max     247.000000     1.000000

# %%
data.columns
# Out:
# Index(['Price', 'Living Area', 'Bathrooms', 'Bedrooms', 'Lot Size', 'Age',
#        'Fireplace'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Price          940
# Living Area    651
# Bathrooms        8
# Bedrooms         6
# Lot Size       158
# Age            128
# Fireplace        2
# dtype: int64

# %%
data['Price'].unique()
# Out:
# array([142212, 134865, 118007, 138297, 129470, 206512,  50709, 108794,
#         68353, 123266, 309808, 157946,  80248, 135708, 173723, 140510,
#        122221, 151917, 235105, 259999, 211517, 102068, 128440, 115659,
#        145583, 116289, 238792, 221925, 310696, 139079, 109578,  65325,
#         89893,  87588, 132311, 131411, 158863, 130490,  88207, 178767,
#        148246, 205073, 185323,  71904,  82556, 199684,  81762,  84291,
#        105363,  45004,  62105, 103508, 157513,  79893,  88770, 115312,
#        118952, 103861, 112649, 127385, 153129, 143808, 133067, 226742,
#         98652, 111394, 101418, 139219, 115248,  99574, 224818, 108459,
#        107919,  45904,  83617, 154723, 101258, 118949, 128717, 136379,
#        124367,  62938, 172016, 106524, 147412, 111221,  75862, 119166,
#        185318, 104749,  44674,  80540,  93773, 109999,  16858, 114326,
#        160995,  59003, 147425, 144695, 130229, 119840, 129723, 133595,
# ...

# %%
# cleaning the dataset

# %%
#check for the null values in the data set

# %%
data.isnull().sum()
# Out:
# Price          0
# Living Area    0
# Bathrooms      0
# Bedrooms       0
# Lot Size       0
# Age            0
# Fireplace      0
# dtype: int64

# %%
# if we have null values we have to deside taht we have to drop  that dataset or 
# or add values to the data  set

# %%
#if we are planning to drop the data 

#house=data.drop(['Living Area','Lot Size'],axis=1)

# %%
#checking for outlier

# %%
# outliers means in statistics outliers is a data point that differs significantly 
# from other observations 

#    for example- if you have a match score which is 72 you know 69 and suddenly somebody has
#             has a 0 and 1 so that is going to be an outlier and an outliers may be the variability in the measurement
#             or it may indicate experimental error are sometimes excluded from the dataset 
#             because an outlier can actually cause serious problems in statistical analysis
#             so thats why we have to look for outliers

# %%
#detecting outliers using Z-Score----z=(x-mean)/std

# %%
outliers=[]   #ouliers as datas or list
def detect_outliers(data): # creating the function which detscts the oulier and  to detect the outliers with the help of z-score we have to find the z-score value    
    
    threshold=3 #if the data is falling in the standard deviation if the data is falling i am not going to consider it has ouliers, if it is falling away from the 3 standard deviation we are going to consider it as oulier  
    mean=np.meanean(data) # 1st i am going to compute the mean 
    std=np.stdtd(data)# then the standard deviation 
    
    # then i am going to put a forloop in to data set 
    for i in data:
        z_score=(i-mean)/std # for each and every dataset i am going to subtaract X-mean to find the z-score , whatever the z-score value commng over here. 
        if np.abs(z_score)>threshold: # if the z-score value is greater than the threshold value,for eg: if its falling away form the 3 standard deviation. i am going to append that i value  in that outliers 
            outliers.append(i) #if its falling away form the 3 standard deviation. i am going to append that i value  in that outliers
            # This particular i values depends that it does not falls in the 3rd std deviation so i am adding that in the outliers list it will check each and every values into the dataset  
    return outliers

# %%
#Outliers_pt=detect_outliers(datasetname)

# %%
#Outliers_pt

# %%
# 3 Relation ship analysis

# %%
# i, we have to do is correlation matrix , correlation matrix  is a table correlation coefficients between variables
#     and each cell in the table shows the correlation between two variables and correlation 
#     matrix is used to summarize data as an input into a more advanced analysis and also a diagonostic for advance analysis

# %%
corelation=data.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns
           ,annot=True)
# Out:
# <AxesSubplot:>

# %%
# lets look into heat map where we have Price,Living Area,Bathroom,Bedrooms,Lot size,Age,Fireplace )

# %%
sns.pairplot(data)

# %%
# pair plot when we want only to visualize the relationship between two variables where the variables can be continuous categorical or boolens
# as well  and pay blood is usually a grid of slots for each variables in your data set as we see we have (Price,Living Area,Bathroom,Bedrooms,Lot size,Age,Fireplace)

# %%
# Scatter plot  (relation plot)

#     Scatter plot is a type of data display that shows the relationship between 
#     two numerical variables each member of data cell gets  plotted as a point whose left 
#     parenthesis and right parenthesis co-ordinates relate to it so values for the two variables

# %%
data.head(1)
# Out:
#     Price  Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace
# 0  142212         1982        1.0         3       2.0  133          0

# %%
sns.relplot(x='Lot Size',y='Bedrooms', hue='Price',data=data)

# %%
# This can be used to minimize our analysis, basically we are plotting three different values inside the same graph
#  so we have the score of two different values that is a readings

# %%
#Histogram

# %%
#Histogram is a graphical display of data using powers of different heights and in histogram each bar groups numbers into ranges so the taller bars shows the mod rate of range actually falls in that and a histogram basically displaced shape and the spread and continuous sample data

# %%
sns.distplot(data['Price'],bins=20)
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
# so we take here as between (100000,200000) we will take a guess as the highest is basically highest that pricing of the house will be highest

# %%
sns.distplot(data['Bedrooms'])
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Bedrooms', ylabel='Density'>

# %%
sns.catplot(x='Price',kind='box',data=data)

# %%
#so we got the catplot graph so the datass which lies between 100000-200000 will have the high datas are falling the same place dso we can check the relationship ,because all these values that are the averages we can check it

# %% [markdown]
# # Linear regression

# %%
# What is regression ?
#      Regression analusis is a form of predictive modelling technique which investigates the relationship between a dependent and independent variable.
#     ii. A regeression analysis involves graphying a line over a set of data points that most closely fits the overall shape of the data or regression shows the changes in a dependent variable in the y- axis to the changes in the explanatory variable on the x-axis.
# What are the uses of regression?
#      Three major uses for regression analysis are 
#          i. Determining the strength of predictors- The first being determining the strength of predictors, the regression might be used to identify the strength of the effect that the independent variables have on the dependent variable.  
#          ii.Forecasting an effect and - In this the regression can be used to forecast effects or impact of changes. That is the regression analysis helped us to understand how much the dependent variable changes with the change in one or more independent variable   
#          iii.Trend forecasting- In this regression analysis to predict trends and future values, the regression analysis can be used to get point estimates

# %%
#Linear regression Selection criteria
#     i. classification and Regression capabilities 
#         Regression models predict continuous variable such as sales made on a day or preddict the temperature of acity their Reliance on a polynomial like a straight line to fit a data set poses a real challenge when it comes towards building a classification capability    
#     ii. Data quality 
#         Remove one data point that could optimize the regression in simple linear regresion the outliers can significantly disrupt the outcomes just for now,you can know that if you remove the outliers your model will become very good
#     iii. Computational complexity 
#           A linear regression is often not computationally expensive as compares to the decision tree or the clustering algorithm the order of complexity for n training example and x features usually falls in either Big O of X square or bigger of xn next is comprehensible 
#      iV. Comprehensible and Transparent 
#            The linear regression are easily comprehensible and transparent in nature.They can be represented by a simple mathematical notation to anyone and can be understood very easily so these are some of the criteria based  which we are selecting the linear regression algorithm

# %%
# Where linear regression used?
#       i. Evaluating Trends and sales Estimates 
#       ii.Analysing the impact of price changes 
#       ii.Assessment of risk in financial services and insurance domain

# %%
#x= independent variable 
#y= dependent variable

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data.head(2)
# Out:
#     Price  Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace
# 0  142212         1982        1.0         3      2.00  133          0
# 1  134865         1676        1.5         3      0.38   14          1

# %%
x=data['Bathrooms'].values
y=data['Price'].values

# %%
# Mean X and Y 
mean_x = np.mean(x)
mean_y = np.mean(y)

# Total number of values 
m=len(x)

#using the formula to calculate b1 and b2 

numer=0
denom=0 

for i in range(m):
    numer+=(x[i]-mean_x)*(y[i]-mean_y)
    denom+=(x[i]-mean_x)**2
b1=numer/denom
b0=mean_y-(b1*mean_x)

#print coefficients 
print(b1,b0)
# Out:
# 70651.20360787046 28329.22879999256

# %%
# plotting values and regression line 

max_x = np.max(x) 
min_x = np.min(x) 

#Calculating line values x and y 

x= np.linspace(min_x,max_x)
y=b0 + b1 * x
# Plotting line 
plt.plot(x,y,color='#58b970', label='Regression line')

#ploting scatter points 

plt.scatter(x,y,c='#ef5423',label='scatter plot')

plt.xlabel('Price according to bedroom')
plt.ylabel('Housing Price')

plt.legend()
plt.show()

# %%
#R-square value

# %%
ss_t=0
ss_r=0

for i in range(m):
    y_pred=b0+b1*x[i]
    ss_t+=(y[i] - mean_y)**2
    ss_r+=(y[i]-y_pred)**2
r2=1-
# Out:
#   File "<ipython-input-54-35cafb05915c>", line 8
#     r2=1-
#          ^
# SyntaxError: invalid syntax

# %%
from sklearn.linear_model import LinearRegression
from  sklearn.metrics import mean_squared_error

x=x.shape ((m,1))

reg=LinearRegression()

reg=reg.fit(x,y)

y_pred=reg.predict(x)

r2_score=reg.score(x,y)

print(r2_score)

# %%
# cancer model data set

# %%
import statsmodels.api as sm
from statsmodels.datasets import cancer

# %%
cancer_data=cancer.load()

# %%
cancer_data.exog_name

# %%
cancer_pandas=cancer.load_pandas()

# %%
cancer_pandas.exog

# %%
x=cancer_data.exog
y=cancer_data.endog

# %%
model=sm.OLS(y,x)

# %%
fit=model.fit()

# %%
fit.pvalues

# %%
fit.summary()

# %% [markdown]
# # Interpreting the Summary table from OLS Statsmodels | Linear Regression

# %%
data.head(3)

# %%
traget_col='Price'

# %%
traget_col

# %%
data_sort=data.sort_values(by=['Price'],axis=0)

# %%
data_sort

# %%
data_sort.mean()

# %%
data_sort.median()

# %%
data_sort.mode()

# %%
dep_var=data_sort['Price']
exp_var=data_sort['Bedrooms']

# %%
exp_var=sm.add_constant(exp_var)

# %%
exp_var

# %%
model=sm.OLS(dep_var,exp_var)
result=model.fit()
print(result.summary())

# %%
conf_int=result.conf_int()

# %%
conf_int

# %%
data.head(2)

# %%
result.predict([1,16858])

# %%
my_plot=plt.figure(figsize=(10,5))
my_plot=plt.plot(data['Price'],data['Fireplace'],'ro',label='housing price data')
my_plot=plt.plot(data['Price'],result.fittedvalues,'b-',label='Regression line')

# %% [markdown]
# # Titanic data set

# %%
tita=pd.read_csv("C:/Users/91944/Desktop/train.csv")

# %%
tita.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
tita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
tita.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
tita.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# Gender plot
sns.factorplot('Sex',data=tita,kind='count')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Pclass',data=tita,kind='count')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Gender distribution among the classes 
sns.factorplot('Pclass',data=tita,hue='Sex',kind='count')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# this give us an insight that there are quite a few males than females in 3rd class. Now lets find how any childers are there

# %%
def titanic_children(passenger):
    age , sex= passenger
    if age <16:
        return 'child'
    else:
        return sex
tita['person']=tita[['Age','Sex']].apply(titanic_children,axis=1)

# %%
sns.factorplot('Pclass',data=tita,hue='person',kind='count')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set(rc={'figure.figsize':(12,10)})
tita['Age'].hist(bins=160)
# Out:
# <AxesSubplot:>

# %%
as_fig=sns.FacetGrid(tita,hue='Sex',aspect=5)
as_fig.map(sns.kdeplot,'Age',shade=True)
oldest=tita['Age'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()

# %%
as_fig=sns.FacetGrid(tita,hue='Pclass',aspect=5)
as_fig.map(sns.kdeplot,'Age',shade=True)
oldest=tita['Age'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()

# %%
tita['Age'].mean()
# Out:
# 29.69911764705882

# %%
tita['Age']=tita['Age'].fillna(tita['Age'].mean())

# %%
tita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  person       891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
tita.drop('Cabin',axis=1,inplace= True)

# %%
tita['Embarked']=tita['Embarked'].fillna('S')

# %%
tita.isnull().values.any()
# Out:
# False

# %%
sns.factorplot('Embarked',data=tita,kind='count')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Embarked',data=tita,hue='Pclass',kind='count')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#lets check who are with family and who are alone
# This can be found by adding parch and sibsp columns

# %%
tita['Alone']=tita.Parch+tita.SibSp
tita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
#  11  person       891 non-null    object
#  12  Alone        891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
sns.factorplot('Alone',kind='count',data=tita)
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Alone',kind='count',data=tita,hue='Pclass')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Survived',data=tita,kind='count')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Survived',data=tita,kind='count',hue='Pclass')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# for 3 rd class passengers

# %%
sns.factorplot('Pclass','Survived',data=tita,hue='Alone')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-cd205e89f3ad> in <module>
# ----> 1 sns.factorplot('Pclass','Survived',data=tita,hue='Alone')
#
# ...

# %%
sns.lmplot('Age','Survived',data=tita)
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('Age','Survived',data=tita,hue='Pclass')
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corr=tita.corr()
plt.figure(figsize=(10,10))

sns.heatmap(corr,vmax=8,linewidths=0.01,
           square=True,annot=True,cmap='YlGnBu',linecolor="White")
plt.title('Correlation between features');

# %%
person_dummies=pd.get_dummies(tita['person'])
alone_dummies=pd.get_dummies(tita['Alone'])

embarked_dummies=pd.get_dummies(tita['Embarked'])
embarked_dummies.drop('Q',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Abijith\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Embarked'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-9158fd7412c8> in <module>
# ...

# %%
plclass_dummies=pd.get_dummies(tita['Pclass'])
plclass_dummies.columns=['class_1','class_2','class_3']

# %%
import math

# %%
tita['Age']=tita['Age'].apply(math.ceil)
tita['Fare']=tita['Fare'].apply(math.ceil)

# %%
tita=pd.concat([tita,plclass_dummies,person_dummies,alone_dummies,embarked_dummies],axis=1)

# %%
tita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    int64
#  10  Embarked     891 non-null    object
#  11  person       891 non-null    object
#  12  Alone        891 non-null    int64
#  13  class_1      891 non-null    uint8
#  14  class_2      891 non-null    uint8
#  15  class_3      891 non-null    uint8
#  16  child        891 non-null    uint8
#  17  female       891 non-null    uint8
#  18  male         891 non-null    uint8
# ...

# %%
tita.drop(['PassengerId','Name','Sex','SibSp','Parch','Ticket','Embarked'],axis=1,inplace=True)
tita.drop(['Alone','person','Pclass','Without Family','male','class_3'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-204-7f51d9822853> in <module>
#       1 tita.drop(['PassengerId','Name','Sex','SibSp','Parch','Ticket','Embarked'],axis=1,inplace=True)
# ----> 2 tita.drop(['Alone','person','Pclass','Without Family','male','class_3'],axis=1,inplace=True)
#
# D:\Abijith\anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# D:\Abijith\anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# ...

# %%
titanic_train=tita.drop('Survived',axis=1)
titanic_survived=tita.Survived

# %%
x_train,x_test,y_train,y_test=train_test_split(titanic_train,titanic_survived,test_size=0.2)

# %%
from sklearn.model_selection import train_test_split

# %%
log_model=LogisticRegression()
log_model.fit(x_train,y_train)
train_survival=log_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-cb0648795dbd> in <module>
# ----> 1 log_model=LogisticRegression()
#       2 log_model.fit(x_train,y_train)
#       3 train_survival=log_model.predict(x_test)
#
# NameError: name 'LogisticRegression' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Machine Learning Tutorial 1 - Linear Regression on Boston Housing Dataset
# | Machine Learning Basics

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt 
# %matplotlib inline

# %%
from sklearn.datasets import load_boston 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
boston=load_boston()

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
 boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston.target #basted on these features we will be finding the target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
datas=boston.data

# %%
type(datas)
# Out:
# numpy.ndarray

# %%
datas.shape
# Out:
# (506, 13)

# %%
datas=pd.DataFrame(data=datas,columns=boston.feature_names)
datas.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT
# 0     15.3  396.9   4.98
# 1     17.8  396.9   9.14

# %%
datas['Price']=boston.target

# %%
datas.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT  Price
# 0     15.3  396.9   4.98   24.0
# 1     17.8  396.9   9.14   21.6

# %% [markdown]
# # Understand your data

# %%
datas.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
 datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
datas.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(datas)

# %%
#distribution plot   for 14 columns including price

# %%
rows=2 
cols=7 #here i am going to plot 2/7  kind of distribution plot for each of the rows and each of the columns to understand the better distribution of the pitches are a distribution of the data 

fig, ax = plt.subplots(nrows= rows,ncols=cols,figsize=(16,4))
col=datas.columns
index=0

# %%
import matplotlib.pyplot as plt

# %%
for i in range (rows):
    for j in range(cols):
        sns.displot(datas[col[index]],ax=ax[i][j])
        index=index + 1
        
plt.tight_layout()

# RM and lstat looks good if it is highly skyed the information to predict your
# Out:
# D:\Abijith\anaconda\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\Abijith\anaconda\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\Abijith\anaconda\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\Abijith\anaconda\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# This is the feature way to select the total feature   this is known as feature selection 
# now we are going to do feature selection with the help of the corelation

# %%
# CORRELATION MATRIX and plot there these skewed features would not much correlated with the final price

# %%
corrmat=datas.corr()
corrmat
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
fig, ax=plt.subplots(figsize=(18,10))
sns.heatmap(corrmat,annot=True,annot_kws={'size':12})
# Out:
# <AxesSubplot:>

# %%
# LSTAT is well corellated with the price 
#Rm also very good well corellated with the price (0.7) here it have positive corellation if Rm increases the price of the house also increasees
# nox and dis is highly correlated  that means that is multicollinearity,if two features are highly correlated to each other

# %%
# function for correlation with the price

# %%
corrmat.index.values
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT', 'Price'], dtype=object)

# %%
def getCorrelatedFeature(corrdata,threshold):
    feature=[]
    value=[]
    
    for i,index in enumerate(corrdata.index):
        if abs(corrdata[index])>threshold:
            feature.append(index)
            value.append(corrdata[index])
    df=pd.DataFrame(data=value,index=feature,columns=['Corr Value'])
    return df

# %%
threshold=0.50
corr_values=getCorrelatedFeature(corrmat['Price'],threshold)
corr_values
# Out:
#          Corr Value
# RM         0.695360
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Price      1.000000

# %%
# here it has selected correlation value more than 0.50 with the price 

# to get good accuracy we have to find the correlation with the help of this

# %%
#Now are are going to set the dats for RM,PTRATIO,LSTAT,Price

# %%
corr_values.index.values
# Out:
# array(['RM', 'PTRATIO', 'LSTAT', 'Price'], dtype=object)

# %%
correlated_data=datas[corr_values.index]

# %%
correlated_data.head()
# Out:
#       RM  PTRATIO  LSTAT  Price
# 0  6.575     15.3   4.98   24.0
# 1  6.421     17.8   9.14   21.6
# 2  7.185     17.8   4.03   34.7
# 3  6.998     18.7   2.94   33.4
# 4  7.147     18.7   5.33   36.2

# %% [markdown]
# # Pair plot for the correlated data

# %%
sns.pairplot(correlated_data)

# %%
sns.heatmap(correlated_data.corr(),annot=True,annot_kws={'size':12})
# Out:
# <AxesSubplot:>

# %%
# each of this are highly correlated to each other , Price highly correlated with LSTAT, Rm and LSTAT are correlated 60% together

# %% [markdown]
# # Shuffle and split data

# %%
x=correlated_data.drop(labels=['Price'],axis=1)
y=correlated_data['Price']

# %%
x.head(2)
# Out:
#       RM  PTRATIO  LSTAT
# 0  6.575     15.3   4.98
# 1  6.421     17.8   9.14

# %%
# x is our feature vector and y is our target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)# random_state=0 we will get almost same amount of accuracy

# %%
x_train.shape,x_test.shape
# Out:
# ((404, 3), (102, 3))

# %% [markdown]
# # Lets train our model

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
df=pd.DataFrame(data=[y_predict,y_test])

# %%
df.T
# Out:
#              0     1
# 0    27.609031  22.6
# 1    22.099034  50.0
# 2    26.529255  23.0
# 3    12.507986   8.3
# 4    22.254879  21.2
# ..         ...   ...
# 97   28.271228  24.7
# 98   18.467419  14.1
# 99   18.558070  18.7
# 100  24.681964  28.1
# 101  20.826879  19.8
#
# [102 rows x 2 columns]

# %% [markdown]
# # How we can evaluate the performance of the matrix

# %%
 # the model with R2 of 0 always fail to predict the target variable that mean, if R2 is low its the very bad model, If r2 is equal to d1 that means its the perfect model it has predicted with 100% accuracy 
    # any values between 0 and 1 the percentage of the target variable thats when there is a high correlation between the predicted and the true target values

# %%
# from sk learn we can import our r2 score

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_predict)
mae=mean_absolute_error(y_test,y_predict)
mse=mean_squared_error(y_test,y_predict)

print('r2_score:',score)
print('mae:',mae)
print('mse:',mse)
# Out:
# r2_score: 0.48816420156925056
# mae: 4.404434993909258
# mse: 41.67799012221684

# %%
correlated_data.columns
# Out:
# Index(['RM', 'PTRATIO', 'LSTAT', 'Price'], dtype='object')

# %% [markdown]
# # Stored features performance

# %%
# stored features into pandas dataframe

# %%
total_features=[]
total_features_name=[]
selected_correlation_value=[]
r2_score=[]
mae_value=[]
mse_value=[]

# %%
# python method for the performance matrix,Why because we will be using this many times

# %%
def performance_metrics(features, th, y_true, y_pred):
    score = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    total_features.append(len(features)-1)
    total_features_name.append(str(features))
    selected_correlation_value.append(th)
    r2_scores.append(score)
    mae_value.append(mae)
    mse_value.append(mse)
    
    metrics_dataframe = pd.DataFrame(data= [total_features_name, total_features, selected_correlation_value, r2_scores, mae_value, mse_value],
                                    index = ['features name', '#feature', 'corr_value', 'r2_score', 'MAE', 'MSE'])
    return metrics_dataframe.T

# %%
performance_metricss(correlated_data.columns.values,threshold,y_test,y_predict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-23590962c555> in <module>
# ----> 1 performance_metricss(correlated_data.columns.values,threshold,y_test,y_predict)
#
# <ipython-input-80-cc67fccb5260> in performance_metricss(features, th, y_true, y_pred)
#       1 def performance_metricss(features, th,y_true,y_pred):
# ----> 2     score=r2_score(y_true,y_pred)
#       3     mae=mean_absolute_error(y_true,y_pred)
#       4     mse=mean_squared_error(y_true,y_pred)
#       5
#
# TypeError: 'list' object is not callable

# %%
rows = 2
cols = 2
fig, ax = plt.subplots(nrows=rows, ncols=cols, figsize = (16, 4))
ax[0, 0].set_title("House price with respect  to RM")
ax[0, 1].set_title("House price with respect to PTRATIO")
ax[1, 0].set_title("House price with respect to LSTAT")
ax[1, 1].set_title("House price with respect to PRICE")
col = correlated_data.columns
index = 0

for i in range(rows):
    for j in range(cols):
        sns.regplot(x = correlated_data[col[index]], y = correlated_data['Price'], ax = ax[i][j])
        index = index + 1
fig.tight_layout()

# %%
corrmat['Price']
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# Price      1.000000
# Name: Price, dtype: float64

# %%
threshold = 0.60
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#        Corr Value
# RM       0.695360
# LSTAT   -0.737663
# Price    1.000000

# %%
correlated_data = datas[corr_value.index]
correlated_data.head()
# Out:
#    LSTAT  Price
# 0   4.98   24.0
# 1   9.14   21.6
# 2   4.03   34.7
# 3   2.94   33.4
# 4   5.33   36.2

# %%
correlated_data.head(2)
# Out:
#    LSTAT  Price
# 0   4.98   24.0
# 1   9.14   21.6

# %%
def get_y_predict(corr_data):
    X = corr_data.drop(labels = ['Price'], axis = 1)
    y = corr_data['Price']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    return y_predict

# %%
y_predict = get_y_predict(correlated_data)
performance_metrics(correlated_data.columns.values, threshold, y_test, y_predict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-f7e0b31f7644> in <module>
#       1 y_predict = get_y_predict(correlated_data)
# ----> 2 performance_metrics(correlated_data.columns.values, threshold, y_test, y_predict)
#
# <ipython-input-121-7eb08961d91e> in performance_metrics(features, th, y_true, y_pred)
#       1 def performance_metrics(features, th, y_true, y_pred):
# ----> 2     score = r2_score(y_true, y_pred)
#       3     mae = mean_absolute_error(y_true, y_pred)
#       4     mse = mean_squared_error(y_true, y_pred)
#       5     total_features.append(len(features)-1)
#
# TypeError: 'list' object is not callable

# %%
corrmat['Price']
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# Price      1.000000
# Name: Price, dtype: float64

# %%
threshold = 0.70
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#        Corr Value
# LSTAT   -0.737663
# Price    1.000000

# %%
correlated_data=datas[corr_value.index]
correlated_data.head()
# Out:
#    LSTAT  Price
# 0   4.98   24.0
# 1   9.14   21.6
# 2   4.03   34.7
# 3   2.94   33.4
# 4   5.33   36.2

# %%
y_predict = get_y_predict(correlated_data)
performance_metrics(correlated_data.columns.values, threshold, y_test, y_predict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-1c8e78f2a5af> in <module>
#       1 y_predict = get_y_predict(correlated_data)
# ----> 2 performance_metrics(correlated_data.columns.values, threshold, y_test, y_predict)
#
# <ipython-input-121-7eb08961d91e> in performance_metrics(features, th, y_true, y_pred)
#       1 def performance_metrics(features, th, y_true, y_pred):
# ----> 2     score = r2_score(y_true, y_pred)
#       3     mae = mean_absolute_error(y_true, y_pred)
#       4     mse = mean_squared_error(y_true, y_pred)
#       5     total_features.append(len(features)-1)
#
# TypeError: 'list' object is not callable

# %%
correlated_data = datas[['RM', 'Price']]
correlated_data.head()
# Out:
#       RM  Price
# 0  6.575   24.0
# 1  6.421   21.6
# 2  7.185   34.7
# 3  6.998   33.4
# 4  7.147   36.2

# %% [markdown]
# # Let’s find out other combination of columns to get better accuracy > 40%

# %%
threshold = 0.40
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#          Corr Value
# INDUS     -0.483725
# NOX       -0.427321
# RM         0.695360
# TAX       -0.468536
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Price      1.000000

# %%
correlated_data = datas[corr_value.index]
correlated_data.head()
# Out:
#    INDUS    NOX     RM    TAX  PTRATIO  LSTAT  Price
# 0   2.31  0.538  6.575  296.0     15.3   4.98   24.0
# 1   7.07  0.469  6.421  242.0     17.8   9.14   21.6
# 2   7.07  0.469  7.185  242.0     17.8   4.03   34.7
# 3   2.18  0.458  6.998  222.0     18.7   2.94   33.4
# 4   2.18  0.458  7.147  222.0     18.7   5.33   36.2

# %%
from sklearn.model_selection import learning_curve, ShuffleSplit

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 10)):
    
    plt.figure()
    plt.title(title)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

X = correlated_data.drop(labels = ['Price'], axis = 1)
y = correlated_data['Price']

title = "Learning Curves (Linear Regression) " + str(X.columns.values)

cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

estimator = LinearRegression()
plot_learning_curve(estimator, title, X, y, ylim=(0.7, 1.01), cv=cv, n_jobs=-1)
plt.show()

# %%
from scipy import stats
stats.probplot(x=datas['Price'],plot=plt)
plt.figure()
